# %%
from dataAnalysis import MulReg
import numpy as np
import matplotlib.pyplot as plt
import csv
# %matplotlib inline

# %%
x1 = []
x2 = []
y = []

with open('MulReg.csv', 'r', newline='') as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        x1.append(float(row[1]))
        x2.append(float(row[2]))
        y.append(float(row[3]))
x1_arr = np.array(x1)
x2_arr = np.array(x2)
y_arr  = np.array(y)
ones = np.ones((1,498))
X_arr = np.vstack((ones, x1_arr, x2_arr)).T

# %%
obj = MulReg(x1_arr, x2_arr, y)
b0, b1, b2 = obj.get_reg()

# %% [markdown]
# ## Not showing as a proper plane

# %%
ax = plt.axes(projection='3d')
ax.plot3D(x1_arr, x2_arr, )
