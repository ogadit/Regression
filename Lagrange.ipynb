# %%
from dataAnalysis import Lagrange
import numpy as np

# %% [markdown]
# #### Data Gathered from the internet

# %%
data = """-5 31.3
-4 19.8
-3 10.9
-2 4.64
-1 1.09
0 0.00
1 0.890
2 3.04
3 5.49
4 7.04
5 6.25""".split('\n')

data = [row.split() for row in data]
x = [float(row[0]) for row in data]
y = [float(row[1]) for row in data]

# %%
Lagrange(x, y, -2.2)
# Out:
# At x0: 5.672012947251201
